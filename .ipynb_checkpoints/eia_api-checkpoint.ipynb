# %% [markdown]
# # Definitions from US Energy Information Administration (EIA)
# ### Primary energy
# Energy in the form that it is first accounted for in a statistical energy balance, before any transformation to secondary or tertiary forms of energy. For example, coal can be converted to synthetic gas, which can be converted to electricity; in this example, coal is primary energy, synthetic gas is secondary energy, and electricity is tertiary energy. See Primary energy production and Primary energy consumption.
#
# ### Primary energy consumption
# Consumption of primary energy.
#
# ### Primary energy production
# Production of primary energy.
#
# ### Primary fuels
# Fuels that can be used continuously. They can sustain the boiler sufficiently for the production of electricity.
#
# #### source: https://www.eia.gov/opendata/qb.php?category=0
# ----------------------------------------------------------------------

# %% [markdown]
# ### In command line interface
# - pip install EIA-python
# - pip install numpy
# - pip install pandas
# - pip install requests

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from config import api_key
import eia
import re

# %%
#test is api_key variable works
#remove this line output when making public
api_key
# Out:
# '021bf1d89256205c8528b6d4475485b3'

# %%
#save variable to call in api data w/ key
api = eia.API(api_key)

# %%
#save all relevant api endings as an iterable object
series=['TOTAL.TEICBUS.M','TOTAL.TERCBUS.M','TOTAL.TEACBUS.M','TOTAL.TXCCBUS.M','TOTAL.TXEIBUS.M','TOTAL.TXICBUS.M','TOTAL.TXRCBUS.M','TOTAL.TXACBUS.M','TOTAL.TETCBUS.M']

# %%
#test one api ending; import to pandas dataframe
newdf=api.data_by_series(series='TOTAL.TECCBUS.M')
dataframe1=pd.DataFrame(newdf)
dataframe1.head()
# Out:
#           Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)
# 1973 01                                            1079.310
# 1973 02                                            1001.920
# 1973 03                                             884.437
# 1973 04                                             735.461
# 1973 05                                             696.114

# %%
import datetime
from datetime import date

# %%
datetime.date(2011, 3, 1)
# Out:
# datetime.date(2011, 3, 1)

# %%
#iterate through api endings and save to above dataframe
for x in series:
    series_search = api.data_by_series(series=x)
    df = pd.DataFrame(series_search)
    dataframe1=dataframe1.join(df, how="outer")

# %%
#print all data in df
dataframe1.head()
# Out:
#           Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 1973 01                                            1079.310
# 1973 02                                            1001.920
# 1973 03                                             884.437
# 1973 04                                             735.461
# 1973 05                                             696.114
#
#           Total Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 1973 01                                            2701.524
# 1973 02                                            2460.752
# 1973 03                                            2579.613
# 1973 04                                            2550.210
# 1973 05                                            2741.810
#
#           Total Energy Consumed by the Residential Sector, Monthly (Trillion Btu)  \
# 1973 01                                            1932.187
# ...

# %%
#add index (unique identifier)
dataframe1=dataframe1.reset_index()
dataframe1=dataframe1.rename(columns={"index":"Time"})
dataframe1.head()
# Out:
#        Time  \
# 0  1973 01
# 1  1973 02
# 2  1973 03
# 3  1973 04
# 4  1973 05
#
#    Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                           1079.310
# 1                                           1001.920
# 2                                            884.437
# 3                                            735.461
# 4                                            696.114
#
#    Total Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 0                                           2701.524
# 1                                           2460.752
# 2                                           2579.613
# 3                                           2550.210
# 4                                           2741.810
#
#    Total Energy Consumed by the Residential Sector, Monthly (Trillion Btu)  \
# 0                                           1932.187
# 1                                           1687.255
# ...

# %%
#call on first item using index 
dataframe1["Time"][0]
# Out:
# '1973 01 '

# %%
#split time calumn into separate year and month (test on first line)
year = re.findall('....', (dataframe1['Time'][0]))[0]
month = re.findall('....', (dataframe1['Time'][0]))[1]

print(f"year = {year}")
print(f"month = {month}")
# Out:
# year = 1973
# month =  01

# %%
#create empty lists for future month and year columns
year = []
month = []
counter = 0

# %%
#iterate to split all time columns into year/month; add to respective list
for time in dataframe1['Time']:
    year.append(re.findall('....', (dataframe1['Time'][counter]))[0])
    month.append(re.findall('....', (dataframe1['Time'][counter]))[1])
    counter = counter + 1

# %%
#add month and year columns to df
dataframe1['Year'] = year
dataframe1['Month'] = month

# %%
dataframe1.head()
# Out:
#        Time  \
# 0  1973 01
# 1  1973 02
# 2  1973 03
# 3  1973 04
# 4  1973 05
#
#    Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                           1079.310
# 1                                           1001.920
# 2                                            884.437
# 3                                            735.461
# 4                                            696.114
#
#    Total Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 0                                           2701.524
# 1                                           2460.752
# 2                                           2579.613
# 3                                           2550.210
# 4                                           2741.810
#
#    Total Energy Consumed by the Residential Sector, Monthly (Trillion Btu)  \
# 0                                           1932.187
# 1                                           1687.255
# ...

# %%
energy_consumption_df = dataframe1[["Year", "Month", "Total Primary Energy Consumption, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Residential Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Transportation Sector, Monthly (Trillion Btu)"]]

# "Total Primary Energy Consumption, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Residential Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Transportation Sector, Monthly (Trillion Btu)"

energy_consumption_df.head()
# Out:
#    Year Month  Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# 0  1973   01                                            7226.265
# 1  1973   02                                            6594.709
# 2  1973   03                                            6524.198
# 3  1973   04                                            5944.336
# 4  1973   05                                            6074.551
#
#    Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                            656.607
# 1                                            621.766
# 2                                            490.154
# 3                                            362.003
# 4                                            289.109
#
#    Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 0                                           2054.675
# 1                                           1869.459
# ...

# %%
datestamp_df = energy_consumption_df = dataframe1[["Time", "Total Primary Energy Consumption, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Residential Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Transportation Sector, Monthly (Trillion Btu)"]]

datestamp_df.head()
# Out:
#        Time  Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# 0  1973 01                                            7226.265
# 1  1973 02                                            6594.709
# 2  1973 03                                            6524.198
# 3  1973 04                                            5944.336
# 4  1973 05                                            6074.551
#
#    Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                            656.607
# 1                                            621.766
# 2                                            490.154
# 3                                            362.003
# 4                                            289.109
#
#    Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 0                                           2054.675
# 1                                           1869.459
# ...

# %%
#side note: api ending for CA monthly generation
#API CALL
#TO USEhttp://api.eia.gov/series/?api_key=YOUR_API_KEY_HERE&series_id=ELEC.GEN.ALL-CA-99.M SERIES
#NAMENet generation : all fuels : California : all sectors : monthly

# %%
plt.figure(figsize=(20,10))
plt.title("Total US Primary Energy Consumption Since 1973")
plt.xlabel("Time")
plt.ylabel("Energy Consumption in Trillion British Thermal Units(BTU)")
plt.xticks(rotation=45)
plt.scatter(datestamp_df['Time'], datestamp_df['Total Primary Energy Consumption, Monthly (Trillion Btu)'], )

# %%
plt.figure(figsize=(20,10))
plt.title("Total US Primary Energy Consumption Since 1973")
plt.xlabel("Time")
plt.ylabel("Energy Consumption in Trillion British Thermal Units(BTU)")
plt.xticks(rotation=45)
plt.plot(datestamp_df['Time'], datestamp_df['Total Primary Energy Consumption, Monthly (Trillion Btu)'], )

# %%
rolling_df = datestamp_df[["Time", "Total Primary Energy Consumption, Monthly (Trillion Btu)"]]

rolling_df.head()
# Out:
#        Time  Total Primary Energy Consumption, Monthly (Trillion Btu)
# 0  1973 01                                            7226.265
# 1  1973 02                                            6594.709
# 2  1973 03                                            6524.198
# 3  1973 04                                            5944.336
# 4  1973 05                                            6074.551

# %%
#create object for timestamp column
timestamp = rolling_df["Time"]

# %%
nospaces = []

# %%
#make new list with spaces removed
for i in timestamp:
    i = i.replace(" ", "-")
    i = i + "01"
    i = pd.to_datetime(i, infer_datetime_format = True)
    nospaces.append(i)

# %%
nospaces
# Out:
# [Timestamp('1973-01-01 00:00:00'),
#  Timestamp('1973-02-01 00:00:00'),
#  Timestamp('1973-03-01 00:00:00'),
#  Timestamp('1973-04-01 00:00:00'),
#  Timestamp('1973-05-01 00:00:00'),
#  Timestamp('1973-06-01 00:00:00'),
#  Timestamp('1973-07-01 00:00:00'),
#  Timestamp('1973-08-01 00:00:00'),
#  Timestamp('1973-09-01 00:00:00'),
#  Timestamp('1973-10-01 00:00:00'),
#  Timestamp('1973-11-01 00:00:00'),
#  Timestamp('1973-12-01 00:00:00'),
#  Timestamp('1974-01-01 00:00:00'),
#  Timestamp('1974-02-01 00:00:00'),
#  Timestamp('1974-03-01 00:00:00'),
#  Timestamp('1974-04-01 00:00:00'),
#  Timestamp('1974-05-01 00:00:00'),
#  Timestamp('1974-06-01 00:00:00'),
#  Timestamp('1974-07-01 00:00:00'),
#  Timestamp('1974-08-01 00:00:00'),
#  Timestamp('1974-09-01 00:00:00'),
#  Timestamp('1974-10-01 00:00:00'),
#  Timestamp('1974-11-01 00:00:00'),
#  Timestamp('1974-12-01 00:00:00'),
#  Timestamp('1975-01-01 00:00:00'),
#  Timestamp('1975-02-01 00:00:00'),
#  Timestamp('1975-03-01 00:00:00'),
# ...

# %%
new_date = np.asarray(nospaces)

# %%
new_date
# Out:
# array([Timestamp('1973-01-01 00:00:00'), Timestamp('1973-02-01 00:00:00'),
#        Timestamp('1973-03-01 00:00:00'), Timestamp('1973-04-01 00:00:00'),
#        Timestamp('1973-05-01 00:00:00'), Timestamp('1973-06-01 00:00:00'),
#        Timestamp('1973-07-01 00:00:00'), Timestamp('1973-08-01 00:00:00'),
#        Timestamp('1973-09-01 00:00:00'), Timestamp('1973-10-01 00:00:00'),
#        Timestamp('1973-11-01 00:00:00'), Timestamp('1973-12-01 00:00:00'),
#        Timestamp('1974-01-01 00:00:00'), Timestamp('1974-02-01 00:00:00'),
#        Timestamp('1974-03-01 00:00:00'), Timestamp('1974-04-01 00:00:00'),
#        Timestamp('1974-05-01 00:00:00'), Timestamp('1974-06-01 00:00:00'),
#        Timestamp('1974-07-01 00:00:00'), Timestamp('1974-08-01 00:00:00'),
#        Timestamp('1974-09-01 00:00:00'), Timestamp('1974-10-01 00:00:00'),
#        Timestamp('1974-11-01 00:00:00'), Timestamp('1974-12-01 00:00:00'),
# ...

# %%
len(new_date)
# Out:
# 549

# %%
#dataframe1['Year'] = year

rolling_df['Date'] = new_date
# Out:
# /Users/julia/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
rolling_df.head()
# Out:
#        Time  Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# 0  1973 01                                            7226.265
# 1  1973 02                                            6594.709
# 2  1973 03                                            6524.198
# 3  1973 04                                            5944.336
# 4  1973 05                                            6074.551
#
#         Date
# 0 1973-01-01
# 1 1973-02-01
# 2 1973-03-01
# 3 1973-04-01
# 4 1973-05-01

# %%
rolling_df["date2"] = pd.to_datetime(rolling_df["Date"], infer_datetime_format = True)
# Out:
# /Users/julia/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
rolling_df.head()
# Out:
#        Time  Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# 0  1973 01                                            7226.265
# 1  1973 02                                            6594.709
# 2  1973 03                                            6524.198
# 3  1973 04                                            5944.336
# 4  1973 05                                            6074.551
#
#         Date      date2
# 0 1973-01-01 1973-01-01
# 1 1973-02-01 1973-02-01
# 2 1973-03-01 1973-03-01
# 3 1973-04-01 1973-04-01
# 4 1973-05-01 1973-05-01

# %%
rolling_df.columns
# Out:
# Index(['Time', 'Total Primary Energy Consumption, Monthly (Trillion Btu)',
#        'Date', 'date2'],
#       dtype='object')

# %%
new_df = rolling_df[["date2", "Total Primary Energy Consumption, Monthly (Trillion Btu)"]]

# %%
new_df = new_df.set_index("date2")

# %%
new_df.head()
# Out:
#             Total Primary Energy Consumption, Monthly (Trillion Btu)
# date2
# 1973-01-01                                           7226.265
# 1973-02-01                                           6594.709
# 1973-03-01                                           6524.198
# 1973-04-01                                           5944.336
# 1973-05-01                                           6074.551

# %%
#test stationality
#if mean is not constant, data is not stationary
#create a rolling mean and a rolling stdev
rollmean=new_df.rolling(window=12).mean()
rollstd=new_df.rolling(window=12).std()

# %%
rollmean.head()
# Out:
#             Total Primary Energy Consumption, Monthly (Trillion Btu)
# date2
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN

# %%
new_df.head(20)
# Out:
#             Total Primary Energy Consumption, Monthly (Trillion Btu)
# date2
# 1973-01-01                                           7226.265
# 1973-02-01                                           6594.709
# 1973-03-01                                           6524.198
# 1973-04-01                                           5944.336
# 1973-05-01                                           6074.551
# 1973-06-01                                           5805.318
# 1973-07-01                                           5954.498
# 1973-08-01                                           6194.365
# 1973-09-01                                           5776.048
# 1973-10-01                                           6177.455
# 1973-11-01                                           6521.876
# 1973-12-01                                           6889.701
# 1974-01-01                                           6906.707
# 1974-02-01                                           6316.938
# ...

# %%
new_df["Rolling Mean"] = rollmean
new_df.head(20)
# Out:
#             Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# date2
# 1973-01-01                                           7226.265
# 1973-02-01                                           6594.709
# 1973-03-01                                           6524.198
# 1973-04-01                                           5944.336
# 1973-05-01                                           6074.551
# 1973-06-01                                           5805.318
# 1973-07-01                                           5954.498
# 1973-08-01                                           6194.365
# 1973-09-01                                           5776.048
# 1973-10-01                                           6177.455
# 1973-11-01                                           6521.876
# 1973-12-01                                           6889.701
# 1974-01-01                                           6906.707
# 1974-02-01                                           6316.938
# ...

# %%
rollmean.head(20)
# Out:
#             Total Primary Energy Consumption, Monthly (Trillion Btu)
# date2
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
# 1973-04-01                                                NaN
# 1973-05-01                                                NaN
# 1973-06-01                                                NaN
# 1973-07-01                                                NaN
# 1973-08-01                                                NaN
# 1973-09-01                                                NaN
# 1973-10-01                                                NaN
# 1973-11-01                                                NaN
# 1973-12-01                                        6306.943333
# 1974-01-01                                        6280.313500
# 1974-02-01                                        6257.165917
# ...

# %%
plt.figure(figsize=(20,10))
plt.xlabel("Year")
plt.ylabel("Consumption")
plt.plot(new_df)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("Year")
plt.ylabel("Consumption")
plt.plot(rollmean)

# %%
plt.figure(figsize=(20,10))
orig=plt.plot(new_df, color="blue", label="Original")
mean=plt.plot(rollmean, color="red", label="Rolling Mean")
std=plt.plot(rollstd, color="black", label="Rolling Std")
plt.legend(loc="best")
plt.title("Rolling Mean and Standard Deviation")
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller
print("Results of Dickey Fuller Test")
dftest=adfuller(new_df["Total Primary Energy Consumption, Monthly (Trillion Btu)"], autolag="AIC")
dfoutput=pd.Series(dftest[0:4], index=["Test Statistic", "P-Value",'# Lags Used',"# of Obsv Used"])
for key, value in dftest[4].items():
    dfoutput["Critical Value (%s)"%key]=value
print(dfoutput)

# from this we know the data is not stationary
# Out:
# Results of Dickey Fuller Test
# Test Statistic           -0.995665
# P-Value                   0.754842
# # Lags Used              14.000000
# # of Obsv Used          534.000000
# Critical Value (1%)      -3.442655
# Critical Value (5%)      -2.866968
# Critical Value (10%)     -2.569661
# dtype: float64

# %%
df3_logScale=np.log(new_df)
plt.plot(df3_logScale)

# %%
movingAverage=df3_logScale.rolling(window=12).mean()
movingStd=df3_logScale.rolling(window=12).std()
plt.plot(df3_logScale)
plt.plot(movingAverage, color="red")

# the data is still not stationary

# %%
#some data uses log to be stationary, some use exponential, some use others....

# %%
datasetLogScaleMinusMovingAverage=df3_logScale-movingAverage
datasetLogScaleMinusMovingAverage.head()
datasetLogScaleMinusMovingAverage.dropna(inplace=True)
datasetLogScaleMinusMovingAverage.head()
# Out:
#             Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# date2
# 1974-11-01                                           0.013471
# 1974-12-01                                           0.106874
# 1975-01-01                                           0.135761
# 1975-02-01                                           0.003345
# 1975-03-01                                           0.037383
#
#             Rolling Mean
# date2
# 1974-11-01     -0.009423
# 1974-12-01     -0.008103
# 1975-01-01     -0.004653
# 1975-02-01     -0.005367
# 1975-03-01     -0.004132

# %%
new_df = datasetLogScaleMinusMovingAverage

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    movingAverage=timeseries.rolling(window=12).mean()
    movingStd=timeseries.rolling(window=12).mean()
    orig=plt.plot(timeseries, color="blue", label="Original")
    mean=plt.plot(movingAverage, color="red", label="Rolling Mean")
    std=plt.plot(movingStd, color="black", label="Rolling STD")
    plt.legend(loc="best")
    plt.title("Rolling Mean and STD")
    plt.show(block=False)
    print("Results of Dickey Fuller test:")
    dfoutput=pd.Series(dftest[0:4], index=["Test Statistic", "P-Value",'# Lags Used',"# of Obsv Used"])
    for key, value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key]=value
    print(dfoutput)

# %%
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Results of Dickey Fuller test:
# Test Statistic           -0.995665
# P-Value                   0.754842
# # Lags Used              14.000000
# # of Obsv Used          534.000000
# Critical Value (1%)      -3.442655
# Critical Value (5%)      -2.866968
# Critical Value (10%)     -2.569661
# dtype: float64

# %%
#test exponential instead of log
df3_logScale=np.log(new_df)
plt.plot(df3_logScale)
# Out:
# /Users/julia/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in log
#   from ipykernel import kernelapp as app
# ...

# %%
movingAverage=df3_logScale.rolling(window=12).mean()
movingStd=df3_logScale.rolling(window=12).std()
plt.plot(df3_logScale)
plt.plot(movingAverage, color="red")

# the data is still not stationary

# %%
datasetLogScaleMinusMovingAverage=df3_logScale-movingAverage
datasetLogScaleMinusMovingAverage.head()
datasetLogScaleMinusMovingAverage.dropna(inplace=True)
datasetLogScaleMinusMovingAverage.head()
# Out:
# Empty DataFrame
# Columns: [Total Primary Energy Consumption, Monthly (Trillion Btu), Rolling Mean]
# Index: []

# %%
new_df = datasetLogScaleMinusMovingAverage

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    movingAverage=timeseries.rolling(window=12).mean()
    movingStd=timeseries.rolling(window=12).mean()
    orig=plt.plot(timeseries, color="blue", label="Original")
    mean=plt.plot(movingAverage, color="red", label="Rolling Mean")
    std=plt.plot(movingStd, color="black", label="Rolling STD")
    plt.legend(loc="best")
    plt.title("Rolling Mean and STD")
    plt.show(block=False)
    print("Results of Dickey Fuller test:")
    dftest = adfuller(timeseries["Total Primary Energy Consumption, Monthly (Trillion Btu)"], autolag = 'AIC')
    dfoutput=pd.Series(dftest[0:4], index=["Test Statistic", "P-Value",'# Lags Used',"# of Obsv Used"])
    for key, value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key]=value
    print(dfoutput)

# %%
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Results of Dickey Fuller test:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-6480840cd3f3> in <module>()
# ----> 1 test_stationarity(datasetLogScaleMinusMovingAverage)
#
# <ipython-input-58-e9481f5a48c0> in test_stationarity(timeseries)
#      10     plt.show(block=False)
#      11     print("Results of Dickey Fuller test:")
# ---> 12     dftest = adfuller(timeseries["Total Primary Energy Consumption, Monthly (Trillion Btu)"], autolag = 'AIC')
#      13     dfoutput=pd.Series(dftest[0:4], index=["Test Statistic", "P-Value",'# Lags Used',"# of Obsv Used"])
#      14     for key, value in dftest[4].items():
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     219
#     220     xdiff = np.diff(x)
# ...

# %%
X = commercial_monthly_df.as_matrix(columns=commercial_monthly_df.columns[2:])

# %%
y = commercial_monthly_df.as_matrix(columns=commercial_monthly_df.columns[1:2])

# %%
print(X)

# %%
shape(X)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")

# %%
#from sklearn import predict
from sklearn.linear_model import predict

# %%
model.predict(201909, 1)

# %%
#make plot better
#widen x axis
#add tickmark labels
#add axis labels
#add title
#make it in the right order?



#get more info on model-
#y=mx+b formula?
#what does r2 score mean?
#what is the p value

# %%
# Arima model time series
#day of week as an input value
#holiday or not?
#create training of one set of time; test on some time in future
