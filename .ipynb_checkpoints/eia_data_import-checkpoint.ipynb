# %%
# This notebook will make an EIA API call to import all relevant consumption data to a dataframe prior to analysis
# one parent dataframe will all data
# primary energy consumption with a single datestamp converted to datetime
# primary energy consumption with a separated month/year for multivariate linear regression

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from config import api_key
import eia
import re
from sklearn.linear_model import LinearRegression

# %%
#test is api_key variable works
#remove this line output when making public
api_key
# Out:
# '021bf1d89256205c8528b6d4475485b3'

# %%
#save variable to call in api data w/ key
api = eia.API(api_key)

# %%
#save all relevant api endings as an iterable object
series=['TOTAL.TEICBUS.M','TOTAL.TERCBUS.M','TOTAL.TEACBUS.M','TOTAL.TXCCBUS.M','TOTAL.TXEIBUS.M','TOTAL.TXICBUS.M','TOTAL.TXRCBUS.M','TOTAL.TXACBUS.M','TOTAL.TETCBUS.M']

# %%
#test one api ending; import to pandas dataframe
newdf=api.data_by_series(series='TOTAL.TECCBUS.M')
dataframe1=pd.DataFrame(newdf)
dataframe1.head()
# Out:
#           Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)
# 1973 01                                            1079.310
# 1973 02                                            1001.920
# 1973 03                                             884.437
# 1973 04                                             735.461
# 1973 05                                             696.114

# %%
import datetime
from datetime import date

# %%
datetime.date(2011, 3, 1)
# Out:
# datetime.date(2011, 3, 1)

# %%
#iterate through api endings and save to above dataframe
for x in series:
    series_search = api.data_by_series(series=x)
    df = pd.DataFrame(series_search)
    dataframe1=dataframe1.join(df, how="outer")

# %%
#print all data in df
dataframe1.head()
# Out:
#           Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 1973 01                                            1079.310
# 1973 02                                            1001.920
# 1973 03                                             884.437
# 1973 04                                             735.461
# 1973 05                                             696.114
#
#           Total Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 1973 01                                            2701.524
# 1973 02                                            2460.752
# 1973 03                                            2579.613
# 1973 04                                            2550.210
# 1973 05                                            2741.810
#
#           Total Energy Consumed by the Residential Sector, Monthly (Trillion Btu)  \
# 1973 01                                            1932.187
# ...

# %%
#add index (unique identifier)
dataframe1=dataframe1.reset_index()
dataframe1=dataframe1.rename(columns={"index":"Time"})
dataframe1.head()
# Out:
#        Time  \
# 0  1973 01
# 1  1973 02
# 2  1973 03
# 3  1973 04
# 4  1973 05
#
#    Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                           1079.310
# 1                                           1001.920
# 2                                            884.437
# 3                                            735.461
# 4                                            696.114
#
#    Total Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 0                                           2701.524
# 1                                           2460.752
# 2                                           2579.613
# 3                                           2550.210
# 4                                           2741.810
#
#    Total Energy Consumed by the Residential Sector, Monthly (Trillion Btu)  \
# 0                                           1932.187
# 1                                           1687.255
# ...

# %%
#call on first item using index 
dataframe1["Time"][0]
# Out:
# '1973 01 '

# %%
#split time calumn into separate year and month (test on first line)
year = re.findall('....', (dataframe1['Time'][0]))[0]
month = re.findall('....', (dataframe1['Time'][0]))[1]

print(f"year = {year}")
print(f"month = {month}")
# Out:
# year = 1973
# month =  01

# %%
#create empty lists for future month and year columns
year = []
month = []
counter = 0

# %%
#iterate to split all time columns into year/month; add to respective list
for time in dataframe1['Time']:
    year.append(re.findall('....', (dataframe1['Time'][counter]))[0])
    month.append(re.findall('....', (dataframe1['Time'][counter]))[1])
    counter = counter + 1

# %%
#add month and year columns to df
dataframe1['Year'] = year
dataframe1['Month'] = month

# %%
# use this parent dataframe to pull relevant info into children dataframes for analysis
dataframe1.head()
# Out:
#        Time  \
# 0  1973 01
# 1  1973 02
# 2  1973 03
# 3  1973 04
# 4  1973 05
#
#    Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                           1079.310
# 1                                           1001.920
# 2                                            884.437
# 3                                            735.461
# 4                                            696.114
#
#    Total Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 0                                           2701.524
# 1                                           2460.752
# 2                                           2579.613
# 3                                           2550.210
# 4                                           2741.810
#
#    Total Energy Consumed by the Residential Sector, Monthly (Trillion Btu)  \
# 0                                           1932.187
# 1                                           1687.255
# ...

# %%
timestamp = dataframe1["Time"]
datetime_list = []

# %%
# fill empty list with dates converted to datetime
for i in timestamp:
    i = i.replace(" ", "-")
    i = i + "01"
    i = pd.to_datetime(i, infer_datetime_format = True)
    datetime_list.append(i)

# %%
datetime_list[:10]
# Out:
# [Timestamp('1973-01-01 00:00:00'),
#  Timestamp('1973-02-01 00:00:00'),
#  Timestamp('1973-03-01 00:00:00'),
#  Timestamp('1973-04-01 00:00:00'),
#  Timestamp('1973-05-01 00:00:00'),
#  Timestamp('1973-06-01 00:00:00'),
#  Timestamp('1973-07-01 00:00:00'),
#  Timestamp('1973-08-01 00:00:00'),
#  Timestamp('1973-09-01 00:00:00'),
#  Timestamp('1973-10-01 00:00:00')]

# %%
# convert to array so it can be added to pandas df
#datetime_array = np.asarray(datetime_list)
#datetime_array[:10]
# Out:
# array([Timestamp('1973-01-01 00:00:00'), Timestamp('1973-02-01 00:00:00'),
#        Timestamp('1973-03-01 00:00:00'), Timestamp('1973-04-01 00:00:00'),
#        Timestamp('1973-05-01 00:00:00'), Timestamp('1973-06-01 00:00:00'),
#        Timestamp('1973-07-01 00:00:00'), Timestamp('1973-08-01 00:00:00'),
#        Timestamp('1973-09-01 00:00:00'), Timestamp('1973-10-01 00:00:00')],
#       dtype=object)

# %%
# make sure this is 549
#len(datetime_array)
# Out:
# 549

# %%
dataframe1['Date'] = datetime_list
dataframe1.head()
# Out:
#        Time  \
# 0  1973 01
# 1  1973 02
# 2  1973 03
# 3  1973 04
# 4  1973 05
#
#    Total Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                           1079.310
# 1                                           1001.920
# 2                                            884.437
# 3                                            735.461
# 4                                            696.114
#
#    Total Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)  \
# 0                                           2701.524
# 1                                           2460.752
# 2                                           2579.613
# 3                                           2550.210
# 4                                           2741.810
#
#    Total Energy Consumed by the Residential Sector, Monthly (Trillion Btu)  \
# 0                                           1932.187
# 1                                           1687.255
# ...

# %%
primary_consumption_yearmonth_df = dataframe1[["Year", "Month", "Total Primary Energy Consumption, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Electric Power Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Residential Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Transportation Sector, Monthly (Trillion Btu)"]]
primary_consumption_yearmonth_df.head()
# Out:
#    Year Month  Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# 0  1973   01                                            7226.265
# 1  1973   02                                            6594.709
# 2  1973   03                                            6524.198
# 3  1973   04                                            5944.336
# 4  1973   05                                            6074.551
#
#    Total Primary Energy Consumed by the Electric Power Sector, Monthly (Trillion Btu)  \
# 0                                           1691.096
# 1                                           1511.458
# 2                                           1559.159
# 3                                           1470.152
# 4                                           1551.631
#
#    Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                            656.607
# 1                                            621.766
# ...

# %%
primary_consumption_datestamp_df = dataframe1[["Date", "Total Primary Energy Consumption, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Electric Power Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Residential Sector, Monthly (Trillion Btu)", "Total Primary Energy Consumed by the Transportation Sector, Monthly (Trillion Btu)"]]
primary_consumption_datestamp_df.head()
# Out:
#         Date  Total Primary Energy Consumption, Monthly (Trillion Btu)  \
# 0 1973-01-01                                           7226.265
# 1 1973-02-01                                           6594.709
# 2 1973-03-01                                           6524.198
# 3 1973-04-01                                           5944.336
# 4 1973-05-01                                           6074.551
#
#    Total Primary Energy Consumed by the Electric Power Sector, Monthly (Trillion Btu)  \
# 0                                           1691.096
# 1                                           1511.458
# 2                                           1559.159
# 3                                           1470.152
# 4                                           1551.631
#
#    Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)  \
# 0                                            656.607
# 1                                            621.766
# ...

# %%
import plotly
import plotly.plotly as py
import cufflinks as cf
from plotly.plotly import plot_mpl
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='disco_nap', api_key='84gBOgUqBKJnD1eR2tFV')

# %%
data = [
    go.Scatter(
        x=primary_consumption_datestamp_df['Date'], # assign x as the dataframe column 'x'
        y=primary_consumption_datestamp_df['Total Primary Energy Consumption, Monthly (Trillion Btu)']
    )
]

layout = go.Layout(title="Total US Primary Energy Consumption Since 1973",
                xaxis=dict(title='Time'),
                yaxis=dict(title='Energy Consumption in Trillion British Thermal Units(BTU)'))

fig = go.Figure(data=data, layout=layout)

url = py.plot(fig, filename='raw_data_line')

# %%
import plotly.tools as tls
tls.embed(url)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~disco_nap/9.embed" height="525" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace_total = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumption, Monthly (Trillion Btu)'],
                  name='Total Consumption',
                  marker=dict(color='red'))

trace_electric = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Electric Power Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Electricity Generation',
                  marker=dict(color='blue'))

trace_commercial = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Commercial Sector',
                  marker=dict(color='green'))

trace_industrial = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Industrial Sector',
                  marker=dict(color='yellow'))

trace_residential = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Residential Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Residential Sector',
                  marker=dict(color='orange'))

trace_transportation = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Transportation Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Transportation Sector',
                  marker=dict(color='orange'))

data = [trace_total, trace_electric, trace_commercial, trace_industrial, trace_residential, trace_transportation]

layout = go.Layout(title="Primary Energy Consumption by Sector",
                xaxis=dict(title='Time'),
                yaxis=dict(title='Energy Consumption in Trillion British Thermal Units(BTU)'))

fig = go.Figure(data=data, layout=layout)

url = py.plot(fig, filename='consumption-by-sector')
# Out:
# 'https://plot.ly/~disco_nap/16'

# %%
tls.embed(url)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~disco_nap/16.embed" height="525" width="100%"></iframe>

# %%
trace_electric = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Electric Power Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Electricity Generation',
                  marker=dict(color='blue'))

trace_commercial = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Commercial Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Commercial Sector',
                  marker=dict(color='green'))

trace_industrial = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Industrial Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Industrial Sector',
                  marker=dict(color='yellow'))

trace_residential = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Residential Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Residential Sector',
                  marker=dict(color='purple'))

trace_transportation = go.Scatter(x=primary_consumption_datestamp_df['Date'],
                  y=primary_consumption_datestamp_df['Total Primary Energy Consumed by the Transportation Sector, Monthly (Trillion Btu)'],
                  name='Consumption by Transportation Sector',
                  marker=dict(color='orange'))

data = [trace_electric, trace_transportation, trace_industrial, trace_commercial, trace_residential]

layout = go.Layout(title="Primary Energy Consumption by Sector",
                xaxis=dict(title='Time'),
                yaxis=dict(title='Energy Consumption in Trillion British Thermal Units(BTU)'))

fig = go.Figure(data=data, layout=layout)

url = py.plot(fig, filename='consumption-by-sector-no-total')
# Out:
# 'https://plot.ly/~disco_nap/18'

# %%
tls.embed(url)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~disco_nap/18.embed" height="525" width="100%"></iframe>

# %%
plt.figure(figsize=(20,10))
plt.title("Total US Primary Energy Consumption Since 1973")
plt.xlabel("Time")
plt.ylabel("Energy Consumption in Trillion British Thermal Units(BTU)")
plt.xticks(rotation=45)
plt.scatter(dataframe1['Time'], dataframe1['Total Primary Energy Consumption, Monthly (Trillion Btu)'])
